# %%
import mysql.connector as sql
import pandas as pd

# %%
conn = sql.connect(user ='root', host = 'localhost', password ='', database = 'books_db')
cur = conn.cursor()

# %%
cur.execute('SHOW TABLES')

for x in cur:
    print(x)
# Out:
# ('books',)

# %%
cur.execute('SELECT * FROM books')
result = cur.fetchall()
for x in result:
    print(x)
# Out:
# (1, 'The Namesake', 'Jhumpa', 'Lahiri', 2003, 32, 291)
# (2, 'Norse Mythology', 'Neil', 'Gaiman', 2016, 43, 304)
# (3, 'American Gods', 'Neil', 'Gaiman', 2001, 12, 465)
# (4, 'Interpreter of Maladies', 'Jhumpa', 'Lahiri', 1996, 97, 198)
# (5, 'A Hologram for the King: A Novel', 'Dave', 'Eggers', 2012, 154, 352)
# (6, 'The Circle', 'Dave', 'Eggers', 2013, 26, 504)
# (7, 'The Amazing Adventures of Kavalier & Clay', 'Michael', 'Chabon', 2000, 68, 634)
# (8, 'Just Kids', 'Patti', 'Smith', 2010, 55, 304)
# (9, 'A Heartbreaking Work of Staggering Genius', 'Dave', 'Eggers', 2001, 104, 437)
# (10, 'Coraline', 'Neil', 'Gaiman', 2003, 100, 208)
# (11, 'What We Talk About When We Talk About Love: Stories', 'Raymond', 'Carver', 1981, 23, 176)
# (12, "Where I'm Calling From: Selected Stories", 'Raymond', 'Carver', 1989, 12, 526)
# (13, 'White Noise', 'Don', 'DeLillo', 1985, 49, 320)
# (14, 'Cannery Row', 'John', 'Steinbeck', 1945, 95, 181)
# (15, 'Oblivion: Stories', 'David', 'Foster Wallace', 2004, 172, 329)
# (16, 'Consider the Lobster', 'David', 'Foster Wallace', 2005, 92, 343)

# %%
pd.read_sql_query('SELECT * FROM books', conn).head()
# Out:
#    book_id                             title author_fname author_lname  \
# 0        1                      The Namesake       Jhumpa       Lahiri
# 1        2                   Norse Mythology         Neil       Gaiman
# 2        3                     American Gods         Neil       Gaiman
# 3        4           Interpreter of Maladies       Jhumpa       Lahiri
# 4        5  A Hologram for the King: A Novel         Dave       Eggers
#
#    released_year  stock_quantity  pages
# 0           2003              32    291
# 1           2016              43    304
# 2           2001              12    465
# 3           1996              97    198
# 4           2012             154    352

# %% [markdown]
# ## String Functions

# %%
q1 = '''SELECT CONCAT(author_fname,' ',author_lname)  as full_name FROM books;'''
pd.read_sql_query(q1,conn).head(4)
# Out:
#        full_name
# 0  Jhumpa Lahiri
# 1    Neil Gaiman
# 2    Neil Gaiman
# 3  Jhumpa Lahiri

# %%
#concat_ws with seperator between all specified columns
q2 = '''SELECT CONCAT_WS(' - ',author_fname,author_lname) as full_name FROM books;'''
pd.read_sql_query(q2,conn).head(3)
# Out:
#          full_name
# 0  Jhumpa - Lahiri
# 1    Neil - Gaiman
# 2    Neil - Gaiman

# %%
#shorten book's title 
q3 = '''SELECT CONCAT(SUBSTR(title,1,10),'...') as short_title FROM books;'''
pd.read_sql_query(q3,conn).head(3)
# Out:
#      short_title
# 0  The Namesa...
# 1  Norse Myth...
# 2  American G...

# %%
q4 = '''SELECT REPLACE(author_fname, 'D', 'J') FROM books;'''
pd.read_sql_query(q4,conn).head()
# Out:
#   REPLACE(author_fname, 'D', 'J')
# 0                          Jhumpa
# 1                            Neil
# 2                            Neil
# 3                          Jhumpa
# 4                            Jave

# %%
q5 = '''SELECT UPPER(author_lname) FROM books;'''
pd.read_sql_query(q5,conn).head()
# Out:
#   UPPER(author_lname)
# 0              LAHIRI
# 1              GAIMAN
# 2              GAIMAN
# 3              LAHIRI
# 4              EGGERS

# %% [markdown]
# ## Aggregate functions

# %%
#How many books are in the database???
q6 = '''SELECT COUNT(*) as Total_books FROM books;'''
pd.read_sql_query(q6,conn).head()
# Out:
#    Total_books
# 0           16

# %%
#How many authors
q7 = '''SELECT COUNT(DISTINCT(author_fname)) as total_authors FROM books;'''
pd.read_sql_query(q7,conn).head()
# Out:
#    total_authors
# 0              9

# %%
#How many titles contain "the"?
q8 = '''SELECT COUNT(*) FROM books WHERE title LIKE '%the%';'''
pd.read_sql_query(q8,conn)
# Out:
#    COUNT(*)
# 0         5

# %%
#COUNT how many books each author has written
q9 = '''SELECT CONCAT(author_fname,' ',author_lname) AS author_name,
        COUNT(*) AS number_of_books
        FROM books
        GROUP BY 1
        ORDER BY 2 DESC'''

pd.read_sql_query(q9,conn)
# Out:
#             author_name  number_of_books
# 0           Neil Gaiman                3
# 1           Dave Eggers                3
# 2        Raymond Carver                2
# 3  David Foster Wallace                2
# 4         Jhumpa Lahiri                2
# 5           Don DeLillo                1
# 6        John Steinbeck                1
# 7        Michael Chabon                1
# 8           Patti Smith                1

# %%
#longest book
q10 = '''SELECT pages FROM books
        ORDER BY pages DESC
        LIMIT 1'''

pd.read_sql_query(q10,conn)
# Out:
#    pages
# 0    634

# %%
#Find the year each author published their first book
q11 = '''SELECT CONCAT(author_fname,' ', author_lname) as author_name, MIN(released_year) FROM books
        GROUP BY 1'''
pd.read_sql_query(q11, conn)
# Out:
#             author_name  MIN(released_year)
# 0           Dave Eggers                2001
# 1  David Foster Wallace                2004
# 2           Don DeLillo                1985
# 3         Jhumpa Lahiri                1996
# 4        John Steinbeck                1945
# 5        Michael Chabon                2000
# 6           Neil Gaiman                2001
# 7           Patti Smith                2010
# 8        Raymond Carver                1981

# %%
#Sum all pages each author has written
q12 = '''SELECT CONCAT(author_fname,' ', author_lname) as author_name, SUM(pages) FROM books
        GROUP BY 1'''
pd.read_sql_query(q12, conn)
# Out:
#             author_name  SUM(pages)
# 0           Dave Eggers      1293.0
# 1  David Foster Wallace       672.0
# 2           Don DeLillo       320.0
# 3         Jhumpa Lahiri       489.0
# 4        John Steinbeck       181.0
# 5        Michael Chabon       634.0
# 6           Neil Gaiman       977.0
# 7           Patti Smith       304.0
# 8        Raymond Carver       702.0

# %%
#Calculate the average stock quantity for books released in the same year
q13 = ''' SELECT released_year, AVG(stock_quantity) as avg_produced FROM books GROUP BY released_year'''
pd.read_sql_query(q13, conn)
# Out:
#     released_year  avg_produced
# 0            1945          95.0
# 1            1981          23.0
# 2            1985          49.0
# 3            1989          12.0
# 4            1996          97.0
# 5            2000          68.0
# 6            2001          58.0
# 7            2003          66.0
# 8            2004         172.0
# 9            2005          92.0
# 10           2010          55.0
# 11           2012         154.0
# 12           2013          26.0
# 13           2016          43.0

# %%
#Find the full name of the author who wrote the longest book
q14 = ''' SELECT CONCAT(author_fname,' ',author_lname) as author_name, MAX(pages) FROM books'''
pd.read_sql_query(q14, conn)
# Out:
#      author_name  MAX(pages)
# 0  Jhumpa Lahiri         634

# %% [markdown]
# ## Logical Operators

# %%
#Select all books NOT published in 2000
q15 = ''' SELECT * FROM books WHERE released_year !=2000'''
pd.read_sql_query(q15, conn)
# Out:
#     book_id                                              title author_fname  \
# 0         1                                       The Namesake       Jhumpa
# 1         2                                    Norse Mythology         Neil
# 2         3                                      American Gods         Neil
# 3         4                            Interpreter of Maladies       Jhumpa
# 4         5                   A Hologram for the King: A Novel         Dave
# 5         6                                         The Circle         Dave
# 6         8                                          Just Kids        Patti
# 7         9          A Heartbreaking Work of Staggering Genius         Dave
# 8        10                                           Coraline         Neil
# 9        11  What We Talk About When We Talk About Love: St...      Raymond
# 10       12           Where I'm Calling From: Selected Stories      Raymond
# 11       13                                        White Noise          Don
# 12       14                                        Cannery Row         John
# 13       15                                  Oblivion: Stories        David
# 14       16                               Consider the Lobster        David
#
#       author_lname  released_year  stock_quantity  pages
# 0           Lahiri           2003              32    291
# 1           Gaiman           2016              43    304
# 2           Gaiman           2001              12    465
# 3           Lahiri           1996              97    198
# 4           Eggers           2012             154    352
# 5           Eggers           2013              26    504
# 6            Smith           2010              55    304
# 7           Eggers           2001             104    437
# 8           Gaiman           2003             100    208
# 9           Carver           1981              23    176
# 10          Carver           1989              12    526
# 11         DeLillo           1985              49    320
# 12       Steinbeck           1945              95    181
# 13  Foster Wallace           2004             172    329
# 14  Foster Wallace           2005              92    343

# %%
#Select books with titles that don't start with 'W'
q16 = '''SELECT * FROM books WHERE title NOT LIKE 'W%' '''
pd.read_sql_query(q16, conn).head()
# Out:
#    book_id                             title author_fname author_lname  \
# 0        1                      The Namesake       Jhumpa       Lahiri
# 1        2                   Norse Mythology         Neil       Gaiman
# 2        3                     American Gods         Neil       Gaiman
# 3        4           Interpreter of Maladies       Jhumpa       Lahiri
# 4        5  A Hologram for the King: A Novel         Dave       Eggers
#
#    released_year  stock_quantity  pages
# 0           2003              32    291
# 1           2016              43    304
# 2           2001              12    465
# 3           1996              97    198
# 4           2012             154    352

# %%
#SELECT books written by Dave Eggers, published after the year 2010
q = ''' SELECT * FROM books WHERE CONCAT(author_fname,' ',author_lname) = 'Dave Eggers' and released_year>2010 '''
pd.read_sql_query(q, conn)
# Out:
#    book_id                             title author_fname author_lname  \
# 0        5  A Hologram for the King: A Novel         Dave       Eggers
# 1        6                        The Circle         Dave       Eggers
#
#    released_year  stock_quantity  pages
# 0           2012             154    352
# 1           2013              26    504

# %%
#Select all books written by Carver,Lahiri,Smith
q = '''SELECT * FROM books WHERE author_lname IN ('Carver','Lahiri','Smith')'''
pd.read_sql_query(q, conn)
# Out:
#    book_id                                              title author_fname  \
# 0        1                                       The Namesake       Jhumpa
# 1        4                            Interpreter of Maladies       Jhumpa
# 2        8                                          Just Kids        Patti
# 3       11  What We Talk About When We Talk About Love: St...      Raymond
# 4       12           Where I'm Calling From: Selected Stories      Raymond
#
#   author_lname  released_year  stock_quantity  pages
# 0       Lahiri           2003              32    291
# 1       Lahiri           1996              97    198
# 2        Smith           2010              55    304
# 3       Carver           1981              23    176
# 4       Carver           1989              12    526

# %%
#I only want books released after 2000 and year is even number
q = '''SELECT * FROM books WHERE released_year>2000 and released_year % 2=0'''
pd.read_sql_query(q, conn)
# Out:
#    book_id                             title author_fname    author_lname  \
# 0        2                   Norse Mythology         Neil          Gaiman
# 1        5  A Hologram for the King: A Novel         Dave          Eggers
# 2        8                         Just Kids        Patti           Smith
# 3       15                 Oblivion: Stories        David  Foster Wallace
#
#    released_year  stock_quantity  pages
# 0           2016              43    304
# 1           2012             154    352
# 2           2010              55    304
# 3           2004             172    329

# %%
#If title contains 'stories'   -> Short Stories,Just Kids-> Memoir,Everything Else -> Novel
q = '''SELECT title, author_fname,
        CASE 
            WHEN title LIKE '%stories%' THEN 'Short Stories'
            WHEN title LIKE '%Just Kids%' THEN 'Memoir'
            ELSE 'Novel'
        END AS 'Genre'
        FROM books;'''
pd.read_sql_query(q, conn)
# Out:
#                                                 title author_fname  \
# 0                                        The Namesake       Jhumpa
# 1                                     Norse Mythology         Neil
# 2                                       American Gods         Neil
# 3                             Interpreter of Maladies       Jhumpa
# 4                    A Hologram for the King: A Novel         Dave
# 5                                          The Circle         Dave
# 6           The Amazing Adventures of Kavalier & Clay      Michael
# 7                                           Just Kids        Patti
# 8           A Heartbreaking Work of Staggering Genius         Dave
# 9                                            Coraline         Neil
# 10  What We Talk About When We Talk About Love: St...      Raymond
# 11           Where I'm Calling From: Selected Stories      Raymond
# 12                                        White Noise          Don
# 13                                        Cannery Row         John
# 14                                  Oblivion: Stories        David
# 15                               Consider the Lobster        David
#
#             Genre
# 0           Novel
# 1           Novel
# 2           Novel
# 3           Novel
# 4           Novel
# 5           Novel
# 6           Novel
# 7          Memoir
# 8           Novel
# 9           Novel
# 10  Short Stories
# 11  Short Stories
# 12          Novel
# 13          Novel
# 14  Short Stories
# 15          Novel

# %%
conn.close()
